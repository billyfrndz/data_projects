# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import classification_report, confusion_matrix, r2_score

df = pd.read_csv("/kaggle/input/weather-forecast-dataset/weather_forecast_data.csv")

# %%
df.sample(5)
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 2314    34.524485  75.827897    7.768912    57.840388  1045.084905  no rain
# 453     12.647654  36.876673   16.502956    64.183098   980.626748  no rain
# 1692    32.491293  40.355326    0.885212    36.821533  1029.104444  no rain
# 999     26.928529  67.902638    6.791015    11.191337  1010.314848  no rain
# 1795    32.624558  57.937856   18.512658    91.605266   996.892550  no rain

# %%
print("Basic Statistics")
print(df.describe())
print("\nData Types")
print(df.info())
# Out:
# Basic Statistics
#        Temperature     Humidity   Wind_Speed  Cloud_Cover     Pressure
# count  2500.000000  2500.000000  2500.000000  2500.000000  2500.000000
# mean     22.581725    64.347094     9.906255    49.658104  1014.312336
# std       7.326996    19.954739     5.780316    29.123104    20.196433
# min      10.001842    30.005071     0.009819     0.015038   980.014486
# 25%      16.359398    47.339815     4.761909    23.900016   996.938630
# 50%      22.536448    63.920797     9.908572    49.488284  1013.433035
# 75%      28.976476    81.561021    14.948408    75.324140  1031.735067
# max      34.995214    99.997481    19.999132    99.997795  1049.985593
#
# Data Types
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  2500 non-null   float64
#  1   Humidity     2500 non-null   float64
#  2   Wind_Speed   2500 non-null   float64
#  3   Cloud_Cover  2500 non-null   float64
#  4   Pressure     2500 non-null   float64
#  5   Rain         2500 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 117.3+ KB
# None

# %%
x = df.drop('Rain', axis = 1)
y = df['Rain']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x.shape)
print(y.shape)
# Out:
# (2500, 5)
# (2500,)

# %%
le = LogisticRegression()
le.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = le.predict(x_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[429  14]
#  [ 20  37]]
#               precision    recall  f1-score   support
#
#      no rain       0.96      0.97      0.96       443
#         rain       0.73      0.65      0.69        57
#
#     accuracy                           0.93       500
#    macro avg       0.84      0.81      0.82       500
# weighted avg       0.93      0.93      0.93       500
